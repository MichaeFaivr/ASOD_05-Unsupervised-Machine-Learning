# %% [markdown]
# # Simulated datasets

# %% [markdown]
# ### Malade depuis le 13mai
# ### aggravation des symptômes
# ### je fais ce que je peux sur les applis au regard de mon état physique diminué

# %% [markdown]
# > 🔦 Along this first exercise, we will train ourselves with some classical generated datasets.

# %%
# TODO: Imports
import numpy as np
from sklearn import datasets
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# ### Q1. Load datasets from scikit-learn datasets using `make_circles`, `make_moons`

# %%
# Load datasets noisy_circles, noisy_moons, and no_structure (ie random data)np.random.seed(42)
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,noise=.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
no_structure = np.random.rand(n_samples, 2), None

# %%
noisy_circles[0]
# Out:
# array([[ 0.03484371,  0.9480112 ],
#        [-0.52128695,  0.7650471 ],
#        [-0.06066061, -0.33708442],
#        ...,
#        [ 0.82209777, -0.51464829],
#        [-0.872323  , -0.51887866],
#        [-0.58250434, -0.04744444]])

# %%
# We give you this last dataset
np.random.seed(170)
X, y = datasets.make_blobs(n_samples=n_samples)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# %% [markdown]
# ### Q2. Explore Data : display & plot datasets

# %%
#TODO: Display datasets content 
X_aniso.shape
# Out:
# (1500, 2)

# %%
y.shape
# Out:
# (1500,)

# %%
#TODO: Plot them on a 2x2 grid using subplots
fig, axs = plt.subplots(2,2,figsize=(10, 10))
# circles
axs[0,0].scatter(noisy_circles[0][:,0], noisy_circles[0][:,1]) ##, c=noisy_circles[1])
# moons
axs[0,1].scatter(noisy_moons[0][:,0], noisy_moons[0][:,1])  ##, c=noisy_moons[1])
# structure
axs[1,0].scatter(no_structure[0][:,0], no_structure[0][:,1])  ##, c=no_structure[1])
# aniso
axs[1,1].scatter(aniso[0][:,0], aniso[0][:,1])  ##, c=aniso[1])
plt.show()

# %% [markdown]
# ### Q3. Agglomerative Clustering on `noisy_circles`

# %%
#TODO: Apply linkage to noisy_circles dataset and display dendrogram
linked = linkage(noisy_circles[0], method='ward') ## more balanced than single
dendrogram(linked)
plt.show()

# %%
#TODO: Apply agglomerative clustering to the dataset
acc = AgglomerativeClustering(n_clusters=2, linkage='single')

# %%
#TODO: Display clusters
labels = acc.fit_predict(noisy_circles[0])

plt.scatter(noisy_circles[0][:,0], noisy_circles[0][:,1], c=labels) #ok avec single // NOK avec ward
plt.show()

# %% [markdown]
# ### Q4. Agglomerative Clustering on other datasets

# %%
#TODO : repeat the same exercise on noisy_moons
acc = AgglomerativeClustering(n_clusters=2, linkage='single')

labels = acc.fit_predict(noisy_moons[0])

plt.scatter(noisy_moons[0][:,0], noisy_moons[0][:,1], c=labels) #ok avec single
plt.show()

# %%
#TODO : repeat the same exercise on no_structure
acc = AgglomerativeClustering(n_clusters=8, linkage='ward')

labels = acc.fit_predict(no_structure[0])

plt.scatter(no_structure[0][:,0], no_structure[0][:,1], c=labels)
plt.show()

# %%
#TODO : repeat the same exercise on aniso
acc = AgglomerativeClustering(n_clusters=3, linkage='complete')

labels = acc.fit_predict(aniso[0])

plt.scatter(aniso[0][:,0], aniso[0][:,1], c=labels)
plt.show()
## voir comment le rendre OK

# %% [markdown]
# What can you conclude on the performance of agglomerative clustering depending on the dataset ?
# Is there any difference with KMeans ?
