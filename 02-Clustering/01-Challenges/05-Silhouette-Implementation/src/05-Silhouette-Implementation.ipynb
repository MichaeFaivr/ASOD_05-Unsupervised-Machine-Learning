# %% [markdown]
# # Challenge - Silhouette

# %% [markdown]
# ![](https://images.unsplash.com/photo-1511367461989-f85a21fda167?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=1189&q=80)

# %% [markdown]
# We will code by ourself the silhouette_sample function.

# %% [markdown]
# ### 1. Random data generation

# %% [markdown]
# The following snippet of code will let you generate some random data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Random data generation
x = np.transpose(np.random.rand(2, 1000) * 20 - 8)
x.shape
# Out:
# (1000, 2)

# %% [markdown]
# Plot the dataset

# %%
# TODO : plot data
plt.scatter(x[:,0], x[:,1], c='blue')
plt.show()

# %% [markdown]
# ### 2. Clustering
# - Use a `KMeans` algorithm to make clusters. Let's consider K = 4 clusters.

# %%
# TODO : Apply KMeans algorithm with K=4
kmeans =  KMeans(n_clusters=4, random_state=42)
# Fit on the data
kmeans.fit(x)
# show the labels
kmeans.labels_
# Out:
# /home/michaelfaivre/.pyenv/versions/3.10.12/envs/artefact/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# array([3, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 2, 0, 1, 2, 2, 3, 1, 3, 1, 0, 3,
#        0, 1, 1, 1, 0, 0, 1, 2, 3, 0, 2, 3, 1, 1, 2, 1, 2, 3, 0, 0, 2, 2,
#        1, 0, 3, 0, 0, 2, 3, 0, 3, 2, 3, 3, 2, 1, 1, 2, 1, 2, 2, 2, 3, 3,
#        0, 2, 0, 2, 0, 3, 0, 0, 1, 3, 0, 0, 0, 0, 0, 2, 3, 1, 3, 3, 3, 2,
#        3, 2, 1, 1, 2, 3, 3, 2, 2, 2, 3, 1, 0, 1, 2, 1, 0, 0, 1, 2, 2, 2,
#        3, 1, 3, 1, 3, 0, 3, 3, 3, 3, 1, 0, 1, 3, 0, 3, 0, 0, 2, 0, 2, 0,
#        0, 3, 1, 2, 1, 1, 3, 1, 3, 2, 3, 3, 2, 2, 0, 2, 1, 3, 1, 3, 0, 3,
#        0, 2, 0, 0, 2, 2, 1, 1, 2, 0, 0, 0, 3, 2, 2, 3, 3, 1, 2, 0, 0, 3,
#        0, 1, 2, 2, 0, 0, 2, 0, 1, 0, 0, 1, 0, 1, 0, 0, 0, 2, 1, 3, 3, 1,
#        1, 2, 0, 1, 1, 2, 1, 0, 1, 1, 0, 2, 2, 3, 1, 0, 1, 0, 2, 0, 2, 0,
#        2, 2, 1, 0, 3, 3, 0, 1, 3, 2, 1, 1, 3, 2, 0, 0, 3, 0, 0, 2, 0, 1,
#        3, 0, 1, 1, 1, 0, 1, 1, 0, 0, 2, 2, 0, 3, 0, 1, 1, 0, 3, 1, 2, 3,
#        1, 0, 0, 0, 3, 0, 1, 1, 2, 0, 2, 1, 1, 1, 2, 0, 2, 3, 2, 2, 2, 1,
#        0, 2, 2, 0, 1, 2, 2, 0, 3, 0, 1, 2, 1, 1, 1, 0, 1, 3, 0, 0, 1, 0,
#        2, 2, 1, 0, 3, 3, 1, 1, 2, 3, 3, 2, 1, 0, 0, 3, 3, 2, 1, 0, 3, 0,
#        0, 3, 0, 2, 1, 0, 0, 3, 2, 1, 3, 1, 0, 2, 3, 0, 2, 3, 2, 0, 3, 0,
#        0, 1, 2, 0, 0, 0, 3, 3, 0, 0, 0, 2, 2, 1, 0, 1, 1, 2, 0, 0, 1, 3,
#        2, 1, 3, 0, 2, 2, 3, 1, 2, 1, 0, 2, 3, 1, 2, 2, 0, 1, 3, 0, 2, 1,
#        2, 3, 1, 0, 1, 3, 1, 2, 3, 1, 1, 3, 3, 2, 1, 3, 1, 0, 1, 3, 2, 0,
#        0, 3, 2, 3, 2, 2, 1, 1, 3, 2, 3, 2, 2, 3, 0, 0, 1, 2, 2, 3, 2, 1,
#        2, 0, 0, 3, 1, 3, 0, 2, 2, 2, 1, 0, 0, 0, 3, 2, 3, 1, 1, 2, 3, 2,
#        0, 3, 2, 0, 1, 0, 3, 3, 3, 2, 1, 3, 3, 0, 2, 2, 0, 2, 3, 1, 3, 1,
#        3, 0, 1, 0, 3, 1, 2, 1, 2, 2, 1, 1, 2, 0, 3, 1, 1, 3, 2, 0, 3, 3,
#        3, 0, 0, 0, 0, 1, 0, 2, 3, 2, 0, 0, 1, 1, 2, 3, 3, 3, 2, 1, 0, 0,
#        1, 3, 0, 3, 2, 1, 2, 1, 0, 0, 3, 1, 3, 2, 2, 3, 2, 0, 3, 1, 2, 2,
#        3, 0, 3, 1, 2, 1, 0, 2, 0, 2, 1, 2, 1, 0, 0, 1, 2, 1, 1, 3, 1, 3,
#        2, 0, 2, 2, 0, 3, 1, 3, 0, 1, 3, 3, 3, 0, 0, 1, 3, 0, 2, 2, 3, 2,
#        2, 3, 3, 0, 3, 1, 3, 0, 3, 3, 1, 2, 1, 3, 2, 2, 2, 0, 3, 2, 0, 3,
#        1, 0, 3, 1, 1, 1, 2, 1, 3, 1, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 1,
#        1, 3, 2, 3, 1, 2, 2, 2, 2, 1, 2, 1, 2, 0, 0, 2, 2, 1, 1, 0, 1, 3,
#        0, 3, 0, 2, 1, 1, 3, 2, 1, 0, 0, 1, 3, 1, 1, 0, 0, 1, 2, 2, 3, 3,
#        2, 2, 2, 1, 2, 1, 2, 0, 1, 2, 1, 3, 2, 2, 3, 0, 3, 3, 3, 0, 0, 3,
#        3, 1, 2, 0, 2, 3, 0, 3, 3, 3, 1, 3, 3, 1, 2, 0, 1, 3, 3, 2, 2, 0,
#        1, 1, 0, 3, 3, 2, 3, 0, 3, 0, 1, 2, 1, 1, 2, 3, 0, 1, 2, 1, 1, 1,
#        2, 3, 3, 3, 2, 3, 1, 1, 2, 3, 2, 0, 0, 1, 2, 1, 0, 0, 2, 3, 1, 0,
#        0, 2, 0, 1, 0, 3, 0, 3, 2, 0, 2, 2, 1, 2, 2, 0, 3, 0, 1, 3, 2, 1,
#        2, 0, 2, 2, 3, 2, 1, 1, 3, 0, 1, 3, 1, 1, 0, 0, 2, 3, 2, 1, 2, 1,
#        2, 0, 3, 0, 1, 2, 0, 3, 0, 1, 2, 3, 1, 2, 2, 0, 2, 1, 3, 0, 2, 0,
#        3, 1, 2, 1, 1, 0, 0, 1, 3, 1, 2, 0, 0, 1, 2, 3, 3, 1, 3, 3, 1, 2,
#        1, 1, 1, 3, 2, 3, 1, 2, 1, 3, 0, 0, 0, 3, 1, 3, 0, 2, 0, 1, 2, 0,
#        3, 3, 0, 3, 3, 0, 2, 2, 1, 0, 1, 1, 1, 1, 0, 0, 2, 0, 3, 0, 2, 0,
#        0, 2, 1, 1, 3, 1, 1, 3, 1, 1, 2, 3, 3, 1, 3, 1, 3, 3, 3, 2, 1, 1,
#        1, 1, 2, 3, 1, 0, 0, 3, 3, 3, 0, 3, 0, 0, 2, 3, 3, 0, 0, 2, 1, 2,
#        2, 1, 0, 1, 2, 0, 1, 1, 1, 3, 1, 2, 1, 0, 3, 2, 3, 3, 0, 0, 3, 0,
#        2, 1, 3, 2, 0, 3, 0, 1, 3, 2, 3, 3, 1, 0, 1, 3, 0, 3, 3, 0, 3, 1,
#        3, 0, 1, 3, 3, 2, 3, 1, 0, 0], dtype=int32)

# %%
# TODO : Get the labels

# %% [markdown]
# - Plot the clusters

# %%
# TODO : plot the data with different colors for the different clusters
# display the clusters
plt.scatter(x[:, 0], x[:, 1], c=kmeans.labels_)

# display the clusters centers
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], marker="*", s=200, c='red')
plt.show()

# %% [markdown]
# ### 3. Silhouette

# %% [markdown]
# ##### Reminder
#
# The Silhouette Coefficient is calculated using the mean intra-cluster distance (a) and the mean nearest-cluster distance (b) for each sample.
#
# The Silhouette Coefficient for a sample is $(b - a) / max(a, b)$
#
# > https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_samples.html

# %% [markdown]
# ##### 3.1 Useful fonctions from previous Challenge
# - the `compute_center` function implemented in th previous exercise will be necessary
# - the `dist` function implemented in th previous exercise will be necessary
#
# > (Just copy/paste them from the previous Challenge)

# %%
# TODO: implement the function compute_center(x)
import math

print(f'x.shape: {x.shape}')

def compute_center(x):
    return x.mean(axis=0)

center = compute_center(x)
print(center.shape)
center


# TODO: implement the function dist(x, center)
def euclid_dist(x, center):
    #if x.shape[1] != 2 or center.shape[1] != 2:
    #    return 'Erreur: 2D arrays attendus'
    sum_squares = (x[0] - center[0]) ** 2 + (x[1] - center[1]) ** 2
    return math.sqrt(sum_squares)
# Out:
# x.shape: (1000, 2)
# (2,)
# array([2.05610899, 2.10286694])

# %% [markdown]
# ###### 3.2 Create the function `get_centers` that returns the cluster center coordinates without using the KMeans attribute.
# - args : `x` and `labels`
#
# - will return the cluster center cooridates

# %%
# TODOD : Create function get_centers
def get_centers(x, labels):
    
    return cluster_center

# %% [markdown]
# ###### 3.3 For a given dataset x, create the functions `cluster` and `nearest_cluster`.
# - args for `cluster`: `x`, `labels`, `i`
#
# - `cluster` will return the coordinates of the cluster of the i_th point of the dataset.
#
# - args for `nearest_cluster`: `x`, `labels`, `i`, `centers`
#
# - `nearest_cluster` the coordinates of the nearest cluster of the i_th point of the dataset.

# %%
# TODO : Create function cluster

# %%
# TODO : Create function nearest_cluster

# %% [markdown]
# ###### 3.4 For a given point ($point=(x_1,x_2)$) , create the functions `a_coef` and `b_coef`:
# - args for `a_coef`: `cluster`, `point`
#
# - `a_coef` will return the *a* value
#
# - args for `b_coef`: `nearest_cluster`, `point`
#
# - `b_coef` will return the *b* value

# %%
# TODO : Create function a_coef

# %%
# TODO : Create function b_coef

# %% [markdown]
# ###### 3.5 Build the `silhouette_values` function:
# - arg : `x` and `labels`
#
# - will return an array of silhouette coefficients

# %%
# TODO : Build silhouette_values function

# %% [markdown]
# ###### 4.6 Get the silhouette values for the clustering you made in question 3 and plot it

# %%
# TODO : Use your silhouette function

# %%
# TODO : Plot the silhouette graph
